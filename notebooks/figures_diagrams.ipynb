# %%
import os
import numpy as np

from IPython.display import Image
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_style('ticks')

matplotlib.rcParams.update({'font.size': 16})
matplotlib.rc('axes', titlesize=16)

from infomercial.exp import meta_bandit
from infomercial.local_gym import bandit
from infomercial.exp.meta_bandit import load_checkpoint
import gym

el = Ellipse((2, -1), 0.5, 0.5)

# %%
fig = plt.figure(figsize=(15, 15))
grid = plt.GridSpec(3, 3)

# -------------------------------------------------------------------
# RL flow
plt.subplot(grid[0, 0], xlim=(0, 1), ylim=(0, 1))
plt.text(-.1, .58, 'Environment', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.75, .58, 'Agent, $\pi$', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.4, .48, 'Action, $A_t$', fontsize=12)
plt.text(.4, .78, 'State, $S_{t}$', fontsize=12)
plt.text(.4, .7, 'Reward, $R_{t}$', fontsize=12)
plt.annotate('', 
             xy=(0.65,0.65), 
             xytext=(0.35,0.65),
             va='center',
             arrowprops=dict(
                 arrowstyle='-|>', 
                 fc="black", 
                 ec="black")
            )
plt.annotate('', 
             xytext=(0.65,0.55), 
             xy=(0.35,0.55),
             va='center',
             arrowprops=dict(
                 arrowstyle='-|>', 
                 fc="black", 
                 ec="black")
            )
plt.axis('off')
# plt.tight_layout()

# -------------------------------------------------------------------
# Info flow
plt.subplot(grid[1, 0], xlim=(0, 1), ylim=(0, 1))
plt.text(-.1, .58, 'Transmitter', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.75, .58, 'Receiver', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.4, .25, 'Noise', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.465, .58, 's', bbox={'facecolor':'black', 'alpha':1, 'pad':.01, 'boxstyle':'circle'})
plt.text(.05, .74, '$x$', fontsize=12)
plt.text(.85, .74, '$y$', fontsize=12)
plt.annotate('', 
             xy=(0.65,0.6), 
             xytext=(0.32,0.6),
             va='center',
             arrowprops=dict(
                 arrowstyle='-|>', 
                 fc="black", 
                 ec="black")
            )
plt.annotate('', 
             xy=(0.48,0.55),
             xytext=(0.48,0.38), 
             va='center',
             arrowprops=dict(
                 ls='--',
                 arrowstyle='-|>', 
                 fc="black", 
                 ec="black")
            )
plt.axis('off')
# plt.tight_layout()

# E flow
plt.subplot(grid[2, 0], xlim=(0, 1), ylim=(0, 1))
plt.text(-.1, .58, 'Environment', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.75, .58, 'Memory, $M$', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.8, 1, 'Agent, $\pi$', fontsize=16, bbox={'facecolor':'grey', 'alpha':0.1, 'pad':.8, 'boxstyle':'round'})
plt.text(.4, .65, 'State, $S_t$', fontsize=12)
plt.text(0.95, 0.8, 'Value, $E_t$', fontsize=12)
plt.text(0.64, 0.8, 'Recall, $Z_t$', fontsize=12)
plt.text(1.1, 0.4, '$\Delta M$', fontsize=12)
plt.annotate('', 
             xy=(0.65,0.6), 
             xytext=(0.35,0.6),
             va='center',
             arrowprops=dict(
                 arrowstyle='-|>', 
                 fc="black", 
                 ec="black")
            )
plt.annotate('',
             xytext=(1.15,.6), 
             xy=(0.9,0.5),
             va='center',
             arrowprops=dict(
                 arrowstyle="-|>",
                 fc="black", 
                 ec="black",
                 connectionstyle="arc,angleA=-30,armA=60,angleB=-90,armB=60,rad=4")
            )
plt.annotate('', 
             xy=(0.9,0.9),
             xytext=(0.9,0.72), 
             va='center',
             arrowprops=dict(
                 arrowstyle='-|>', 
                 fc="black", 
                 ec="black")
            )
plt.axis('off')
# plt.tight_layout()
# Out:
# (0.0, 1.0, 0.0, 1.0)
